# %%
# %cd drive/MyDrive/WemanityCodeChallenge/
# Out:
# /content/drive/MyDrive/WemanityCodeChallenge

# %%
# !git config --global user.email "benraisdotlamine@gmail.com"
# !git config --global user.name "benraisdotlamine"
Token='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'

# %%
# !echo "# wemanityCodeChallenge2" >> README.md
# !git init
# !git add -A
# !git commit -m "update changes"
# !git branch -M main
# !git remote remove origin
# !git remote add origin https://{Token}@github.com/benraisdotlamine/wemanityCodeChallenge.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/WemanityCodeChallenge/.git/
# [main 9af7b6c] update changes
#  6 files changed, 433 insertions(+), 12 deletions(-)
#  create mode 100644 AnalyseDesDonnees.ipynb
#  create mode 100644 Data/chronic_kidney_disease.arff
#  rewrite GitUpdate.ipynb (83%)
#  create mode 100644 Untitled0.ipynb
#  delete mode 100644 untitled
# fatal: could not read Password for 'https://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@github.com': No such device or address
